# %% [markdown]
# <a href="https://colab.research.google.com/github/MikeDeecode/Campus-placement-project/blob/master/campus_placement_MLR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 

print("Setup complete")
# Out:
# Setup complete
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
placement = pd.read_csv("/content/Placement_Data_(viz).csv", index_col = 0)
print ("Success")
# Out:
# Success

# %%
placement.head()
# Out:
#       gender  ssc_p    ssc_b  hsc_p  ... specialisation  mba_p      status    salary
# sl_no                                ...
# 1          M  67.00   Others  91.00  ...         Mkt&HR  58.80      Placed  270000.0
# 2          M  79.33  Central  78.33  ...        Mkt&Fin  66.28      Placed  200000.0
# 3          M  65.00  Central  68.00  ...        Mkt&Fin  57.80      Placed  250000.0
# 4          M  56.00  Central  52.00  ...         Mkt&HR  59.43  Not Placed       NaN
# 5          M  85.80  Central  73.60  ...        Mkt&Fin  55.50      Placed  425000.0
#
# [5 rows x 14 columns]

# %%
sns.regplot('ssc_p', 'salary', data = placement)
plt.show()

# %%
sns.regplot('hsc_p', 'salary', data = placement)
plt.show()

# %%
sns.regplot('degree_p', 'salary', data = placement)
plt.show()

# %%
sns.regplot('etest_p', 'salary', data = placement)
plt.show()

# %%
sns.regplot('mba_p', 'salary', data = placement)
plt.show()

# %%
features = placement[['hsc_p', 'etest_p', 'mba_p', 'salary']]

# %%
msk = np.random.rand(len(placement)) < 0.8
train = features[msk]
test = features[~msk]

# %%
from sklearn import linear_model

# %%
model =  linear_model.LinearRegression()
x = np.asanyarray(train[['hsc_p']])
